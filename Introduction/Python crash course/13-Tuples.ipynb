# %% [markdown]
# ### A tuple is a sequence of immutable Python objects. Tuples are sequences, just like lists.
# ### The differences between tuples and lists are, the tuples cannot be changed unlike lists and
# ### tuples use parentheses, whereas lists use square brackets.

# %%
tup1 = ('A', 'B', 1, 2, 27, 200)
tup2 = (1, 2, 3, 4, 5 )

# %%
print(tup1)
print(" ")
print(tup2)
# Out:
# ('A', 'B', 1, 2, 27, 200)
#
# (1, 2, 3, 4, 5)

# %% [markdown]
# # Length of Tuple

# %%
len(tup1)
# Out:
# 6

# %% [markdown]
# # Indexing and Slicing

# %%
tup1[0]
# Out:
# 'A'

# %%
tup2[4]
# Out:
# 5

# %%
tup2[1:4]
# Out:
# (2, 3, 4)

# %%
import numpy as np
tup = ( np.random.rand(3,3), [1,2,3] )

# %%
print(tup)
# Out:
# (array([[0.718644  , 0.32647618, 0.20427484],
#        [0.8818119 , 0.36253853, 0.42648404],
#        [0.51793005, 0.24303656, 0.82654741]]), [1, 2, 3])

# %%
len(tup)
# Out:
# 2

# %%
tup[0]
# Out:
# array([[0.718644  , 0.32647618, 0.20427484],
#        [0.8818119 , 0.36253853, 0.42648404],
#        [0.51793005, 0.24303656, 0.82654741]])

# %%
tup[1]
# Out:
# [1, 2, 3]

# %% [markdown]
# ### Tuples are immutable which means you cannot update or change the values of tuple elements

# %%
tup2[0] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-1020dd4ab04b> in <cell line: 1>()
# ----> 1 tup2[0] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### Tuple Concatenation

# %%
tup3 = tup1 + tup2;

# %%
tup3
# Out:
# ('A', 'B', 1, 2, 27, 200, 1, 2, 3, 4, 5)

# %% [markdown]
# # More on Tuples

# %%
set(tup1) & set(tup2)  # Finding Common elements in Tuples
# Out:
# {1, 2}

# %%
max(tup2)
# Out:
# 5

# %%
min(tup2)
# Out:
# 1
