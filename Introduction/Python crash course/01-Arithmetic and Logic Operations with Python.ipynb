# %% [markdown]
# # Addition, Subtraction, Multiplication and Division

# %%
2 + 3
# Out:
# 5

# %%
5-2
# Out:
# 3

# %%
3 * 4
# Out:
# 12

# %%
5/2
# Out:
# 2.5

# %%
5//2
# Out:
# 2

# %% [markdown]
# # Exponent or Power

# %%
3 ** 2   # 3 raise to power 2 OR 3 square
# Out:
# 9

# %%
2 ** 3  # 2 raise to power 3
# Out:
# 8

# %%
25 ** 0.5  # square root of 25
# Out:
# 5.0

# %% [markdown]
# # Order of operations

# %%
2*3 + 5 + 5*2 + 3 # Multiplication executes first.
# Out:
# 24

# %% [markdown]
# ###  BODMAS (Bracket open, Division, Multiplication, Addition, Subtraction)

# %%
80 / 2*4
# Out:
# 160.0

# %%
80 / (2*4) # use paranthesis
# Out:
# 10.0

# %%
2+5 * 3+2
# Out:
# 19

# %%
(2+5) * (3+2)
# Out:
# 35

# %% [markdown]
# # Modulo Operator

# %%
8 % 4  # Remainder after division
# Out:
# 0

# %%
7 % 4
# Out:
# 3

# %%
21 % 7
# Out:
# 0

# %% [markdown]
# # Variable Assignment

# %%
a = 3

# %%
a ** 2
# Out:
# 9

# %%
b = 4

# %%
b ** a
# Out:
# 64

# %%
a * b
# Out:
# 12

# %% [markdown]
# # Comparison Operator

# %%
2 > 3            #   2 is greater than 3
# Out:
# False

# %%
5 < 6            #  5 is less than 6
# Out:
# True

# %%
3 == 5           #   3 is equal to 5
# Out:
# False

# %%
b = 4

# %%
b == 4
# Out:
# True

# %%
5 >= 4            # 5 is greater or equal to 4
# Out:
# True

# %%
4 >= 4
# Out:
# True

# %%
4 != 4            # 4 is not equal to 4
# Out:
# False

# %%
5 != 4
# Out:
# True

# %%
5 <= 6
# Out:
# True

# %%
5 <= 4
# Out:
# False

# %%
4 <= 5
# Out:
# True

# %% [markdown]
# # Logic Operators

# %% [markdown]
# ### and Operator will return true if all the comparison statements are true

# %%
(3 > 2) and (4 > 3)
# Out:
# True

# %%
(3 > 2) and (4 < 3)
# Out:
# False

# %% [markdown]
# ### or Operator will return true if any of the comparison statements are true

# %%
(3 > 2) or (4 < 3)
# Out:
# True

# %%
(2 > 3) or (3 > 4)
# Out:
# False

# %% [markdown]
# # Conditional Statements

# %% [markdown]
# ## if and else are keywords in Conditional Statements

# %% [markdown]
# ##  if ( conditional statement ):
# ###       execute the code if conditional statement is True
# ##  else:
# ###       execute the code if conditional statement is False

# %%
x = 4

if x == 4:
    print("Correct")
else:
    print("Wrong")
# Out:
# Correct

# %%
x = 4

if x != 4:
    print("Correct")
else:
    print("Wrong")
# Out:
# Wrong

# %% [markdown]
# ### if, elif and else statement

# %%
x = 3
y = 4

if (x == 4) and (y == 4):
    print(" First")
    
elif (x == 3) and (y == 4):
    print("Second")
    
else:
    print("Correct your statements")
# Out:
# Second

# %%
x = 3
y = 4

if (x == 4) and (y == 4):
    print(" First")
    
elif (x == 3) and (y == 5):
    print("Second")
    
else:
    print("Correct your statements")
# Out:
# Correct your statements

# %%
x = 3
y = 4

if (x == 3) and (y == 4):
    print(" First")
    
elif (x == 3) and (y == 5):
    print("Second")
    
else:
    print("Correct your statements")
# Out:
#  First

# %%
x = 3
y = 4

if (x == 3) or (y == 5):
    print(" First")
    
elif (x == 3) and (y == 4):
    print("Second")
    
else:
    print("Correct your statements")
# Out:
#  First
