# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Introduction to Google Colab
# Out:
# /content/drive/MyDrive/Introduction to Google Colab

# %% [markdown]
# # Reading dataset

# %%
data = pd.read_csv("MySignalDataset.csv")

# %%
data.head()
# Out:
#    -0.247837063435355  -0.238147812174743  -0.224115103452477  \
# 0           -0.470356           -0.460834           -0.458996
# 1           -0.115696           -0.105505           -0.099658
# 2           -0.363774           -0.368786           -0.360099
# 3           -0.195047           -0.193711           -0.205405
# 4           -0.344395           -0.354419           -0.335709
#
#    -0.224449215564912  -0.233804354713089  -0.234138466825524  \
# 0           -0.462003           -0.461335           -0.456323
# 1           -0.093811           -0.088967           -0.087129
# 2           -0.348405           -0.330864           -0.321342
# 3           -0.219939           -0.227456           -0.222110
# 4           -0.314659           -0.300293           -0.288933
#
#    -0.217766973316214  -0.213590571910777  -0.207075385718297  \
# 0           -0.449641           -0.439116           -0.411552
# 1           -0.095148           -0.108679           -0.117032
# ...

# %%
data.shape
# Out:
# (6090, 257)

# %%
data.iloc[:,-1].value_counts()
# Out:
# 1    3226
# 2    1859
# 0    1005
# Name: 0, dtype: int64

# %%
plt.plot(data.iloc[10,:-1].values)
